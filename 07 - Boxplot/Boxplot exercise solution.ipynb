# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dat=pd.read_excel('C:/YellowBelt/Moisture_data.xlsx')
dat.head()
# Out:
#             Timestamp  Moisture_content
# 0 2020-01-01 00:00:00              3.21
# 1 2020-01-01 01:00:00              3.13
# 2 2020-01-01 02:00:00              3.22
# 3 2020-01-01 03:00:00              3.20
# 4 2020-01-01 04:00:00              3.19

# %%
fig=plt.figure(figsize=(8,7))
ax=fig.add_subplot(111)
ax.boxplot(dat['Moisture_content'])
ax.axhline(4,color='red')
ax.set_ylabel('%')
ax.set_title('Milk powder production line')
ax.grid(True)

# %%
dat['month']=dat['Timestamp'].dt.month
dat.head()
# Out:
#             Timestamp  Moisture_content  month
# 0 2020-01-01 00:00:00              3.21      1
# 1 2020-01-01 01:00:00              3.13      1
# 2 2020-01-01 02:00:00              3.22      1
# 3 2020-01-01 03:00:00              3.20      1
# 4 2020-01-01 04:00:00              3.19      1

# %%
fig=plt.figure(figsize=(15,7))
ax=fig.add_subplot(111)
sns.boxplot(data=dat,y='Moisture_content',x='month')
ax.axhline(4,color='red')
ax.set_ylabel('%')
ax.set_title('Milk powder production line')
ax.grid(True)
